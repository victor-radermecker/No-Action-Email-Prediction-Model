# %%
import pandas as pd
from cleaning_pipeline import * 

import warnings
warnings.filterwarnings('ignore')

# automatically refresh imported modules
# %reload_ext autoreload
# %autoreload 2

# %%
# Store data locally for confidentiality reasons!
data_path = "/Users/victor/Documents/Confidential Dataset/ML_NOAC_NOVA_Extraction.csv"

# Read data
df = pd.read_csv(data_path)

# split the dataset in two equal parts
# df1 = df.iloc[: int(len(df) / 2), :]
# df2 = df.iloc[int(len(df) / 2) :, :]

# path1 = "/Users/victor/Documents/Confidential Dataset/ML_NOAC_NOVA_Extraction_Cleaned_DF1.csv"
# path2 = "/Users/victor/Documents/Confidential Dataset/ML_NOAC_NOVA_Extraction_Cleaned_DF2.csv"

# %%
path3 = "/Users/victor/Documents/Confidential Dataset/ML_NOAC_NOVA_Extraction_Cleaned_DF3_Full.csv"
path4 = "/Users/victor/Documents/Confidential Dataset/ML_NOAC_NOVA_Extraction_Cleaned_DF4_Full.csv"

# %%
data_cleaning(df, path4, lemmatize=False, stopwords=False, english_words=False)
# Out:
# 100%|██████████| 251234/251234 [01:15<00:00, 3315.37it/s]
# Cleaning completed. :)
#          index  CaseNumber  Type Topics                      TeamName  \
# 0            0   100124562     0   T039      US-NOR-CMA-BKG-PREFERRED
# 1            1   100080371     0   T036  US-BNA-CMA-CS-IMP-DIVERSIONS
# 2            2   100095395     0   T035      US-NOR-CMA-BKG-PREFERRED
# 3            3   100097054     0   T847      US-NOR-CMA-BKG-SPECIALTY
# 4            4   100097055     0   T847      US-NOR-CMA-BKG-SPECIALTY
# ...        ...         ...   ...    ...                           ...
# 251229  251229   102470077     1   T848           US-NOR-CMA-DISPUTES
# 251230  251230   102510003     1   T701           US-NOR-CMA-DISPUTES
# 251231  251231   102509997     1   T701           US-NOR-CMA-DISPUTES
# 251232  251232   102513703     0   T044            US-NOR-CMA-IMP-CVS
# 251233  251233   102499107     1   T701  US-BNA-CMA-CS-EXP-DIVERSIONS
#
#                        RequesterEmail  \
# 0                                 NaN
# 1                                 NaN
# 2           tina@generallogistics.net
# 3          bookings@delongcompany.com
# 4          bookings@delongcompany.com
# ...                               ...
# 251229      jadec@westernoverseas.com
# 251230          abarraza@mgfgroup.com
# 251231          abarraza@mgfgroup.com
# 251232  usa.logexland@usa.cma-cgm.com
# 251233        orders@midcitiesinc.com
#
#                                               EmailObject  \
# 0                                            NAM4999926A
# 1                         MOGELIJKE COD'S F119086 // RTM
# 2                           AMEND NAM5088900  [ ref:_00D
# 3                         FW: CMA CGM - Cut-off date cha
# 4                         FW: CMA CGM - Cut-off date cha
# ...                                                   ...
# 251229  RE: ***URGENT***OCE0219991 DET Invoice #USAE00...
# 251230  DISPUTE INV USAE0062674 - BKG  Invoice #USAE00...
# 251231  Re: DISPUTE INV USAE0062674 -  Invoice #USAE00...
# 251232                    FW: USCHI - Australia containe
# 251233                    RE: USKCK: AEL1117434 - SEGU19
#
#                                        LastEmailCCAddress       AttributesURL  \
# 0                                      op@easywayintl.com  5005p00002evRjHAAU
# 1       janneke.van.leeuwen@fclmarine.nl; executivedes...  5005p00002evWsuAAE
# 2                           bookings@generallogistics.net  5005p00002evX4SAAU
# 3                     usa.cmaexportactive@usa.cma-cgm.com  5005p00002evXIsAAM
# 4                                                     NaN  5005p00002evXItAAM
# ...                                                   ...                 ...
# 251229  spe@westernoverseas.com; may.tang@apl.com; ron...  5005p00002hIgL5AAK
# 251230  orf.wsaunders@cma-cgm.com; anishigaya@mgfgroup...  5005p00002hIsV3AAK
# 251231  orf.wsaunders@cma-cgm.com; anishigaya@mgfgroup...  5005p00002hIsYnAAK
# 251232  rfiexportrailbilling@cma-cgm.com; usa.mhackett...  5005p00002hItpYAAS
# 251233  usa.tbriggs@usa.cma-cgm.com; usa.mguffie@usa.c...  5005p00002hIopWAAS
#
#        ContactAttributesURL                      ContactEmail  \
# 0        0035p00003aZAdZAAW         usa.wcportops@cma-cgm.com
# 1        0030N00003N771RQAR  janneke.van.leeuwen@fclmarine.nl
# 2        0030N00002x1JqPQAU         tina@generallogistics.net
# 3        0030N00002tXvvIQAS        bookings@delongcompany.com
# 4        0030N00002tXvvIQAS        bookings@delongcompany.com
# ...                     ...                               ...
# 251229   0035p00003aexrjAAA         jadec@westernoverseas.com
# 251230   0035p00003UVJ3xAAH             abarraza@mgfgroup.com
# 251231   0035p00003UVJ3xAAH             abarraza@mgfgroup.com
# 251232   0030N00002nV8DBQA0     usa.logexland@usa.cma-cgm.com
# 251233   0030N000032cDNdQAM           orders@midcitiesinc.com
#
#                                  LastIncomingEmailContent  \
# 0        \nThank you Jessica! Await your further on th...
# 1       \nHi Nese,\n \nInmiddels de aangepaste bl’s al...
# 2       \nHello,\nPlease SPLIT subject line booking to...
# 3       CMA CGM - Cut-off date change at - NEW YORK, N...
# 4       CMA CGM - Cut-off date change at - NEW YORK, N...
# ...                                                   ...
# 251229  **** THIS MESSAGE WAS TRUNCATED ****\nUSA Disp...
# 251230  Dear Disputes Team, We have received the attac...
# 251231  Adding ANL disputes Team, We have received the...
# 251232  ***This Message was Truncated***\nIMP CSV,\n \...
# 251233  \nPlease reach out to them as they are wanting...
#
#         LastEmailCCAddressCount  CMA_in_cc  CountMailsInConversation  \
# 0                             1      False                         7
# 1                             5       True                         4
# 2                             1      False                         3
# 3                             1       True                         2
# 4                             0      False                         2
# ...                         ...        ...                       ...
# 251229                        3      False                        12
# 251230                        2       True                         1
# 251231                        2       True                         1
# 251232                        2       True                        12
# 251233                        2       True                        12
#
#                                          LastEmailContent
# 0       thank you jessica await your further on the tw...
# 1       hi nese inmiddels de aangepaste bls al beschik...
# 2       hello please split subject line booking to the...
# 3       cma cgm cutoff date change at new york ny us u...
# 4       cma cgm cutoff date change at new york ny us u...
# ...                                                   ...
# 251229   this message was truncated usa disputes pls s...
# 251230  dear disputes team we have received the attach...
# 251231  adding anl disputes team we have received the ...
# 251232  this message was truncated imp csv please reac...
# 251233  please reach out to them as they are wanting u...
#
# [251234 rows x 16 columns]

# %%
# nltk.download('omw-1.4')
# nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /Users/victor/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
pd.set_option('display.max_rows', 1000)

path1 = "/Users/victor/Documents/Confidential Dataset/ML_NOAC_NOVA_Extraction_Cleaned_DF1.csv"
df = pd.read_csv(path1)

# %%
path1 = "/Users/victor/Documents/Confidential Dataset/ML_NOAC_NOVA_Extraction_Cleaned_DF1.csv"
path2 = "/Users/victor/Documents/Confidential Dataset/ML_NOAC_NOVA_Extraction_Cleaned_DF2.csv"

# %%
df1 = pd.read_csv(path1)
df2 = pd.read_csv(path2)

# %%
df = df1.append(df2)

df.head(1000)
# Out:
#      index  CaseNumber  Type Topics                      TeamName  \
# 0        0   100124562     0   T039      US-NOR-CMA-BKG-PREFERRED
# 1        3   100080371     0   T036  US-BNA-CMA-CS-IMP-DIVERSIONS
# 2        4   100095395     0   T035      US-NOR-CMA-BKG-PREFERRED
# 3        5   100097054     0   T847      US-NOR-CMA-BKG-SPECIALTY
# 4        6   100097055     0   T847      US-NOR-CMA-BKG-SPECIALTY
# ..     ...         ...   ...    ...                           ...
# 995   3368   100806052     0   T065      US-NOR-CMA-IMP-PREFERRED
# 996   3369   100804935     0   T065      US-NOR-CMA-IMP-PREFERRED
# 997   3373   100805290     0   T539   US-NOR-CMA-EXP-PMR-RIOTINTO
# 998   3375   100806330     0   T539   US-NOR-CMA-CS-EXP-PREFERRED
# 999   3376   100805903     0   T847       US-NOR-CMA-CS-STARS-DHL
#
#                  RequesterEmail                      EmailObject  \
# 0                           NaN                     NAM4999926A
# 1                           NaN  MOGELIJKE COD'S F119086 // RTM
# 2     tina@generallogistics.net    AMEND NAM5088900  [ ref:_00D
# 3    bookings@delongcompany.com  FW: CMA CGM - Cut-off date cha
# 4    bookings@delongcompany.com  FW: CMA CGM - Cut-off date cha
# ..                          ...                              ...
# 995  colleen@hansenshipping.com                              NaN
# 996                         NaN                              NaN
# 997                         NaN  CJX Need Docs for NAM4847706/R
# 998                         NaN                     NAM4947358B
# 999                         NaN   FW: Cardinal Health business
#
#                                     LastEmailCCAddress       AttributesURL  \
# 0                                   op@easywayintl.com  5005p00002evRjHAAU
# 1    janneke.van.leeuwen@fclmarine.nl; executivedes...  5005p00002evWsuAAE
# 2                        bookings@generallogistics.net  5005p00002evX4SAAU
# 3                  usa.cmaexportactive@usa.cma-cgm.com  5005p00002evXIsAAM
# 4                                                  NaN  5005p00002evXItAAM
# ..                                                 ...                 ...
# 995  holly@hansenshipping.com; james.bowen@tos-ship...  5005p00002evnVpAAI
# 996                                                NaN  5005p00002evnVtAAI
# 997                usa.cmaexportactive@usa.cma-cgm.com  5005p00002evnWXAAY
# 998                                                NaN  5005p00002evnXgAAI
# 999                                                NaN  5005p00002evnXqAAI
#
#     ContactAttributesURL                      ContactEmail  \
# 0     0035p00003aZAdZAAW         usa.wcportops@cma-cgm.com
# 1     0030N00003N771RQAR  janneke.van.leeuwen@fclmarine.nl
# 2     0030N00002x1JqPQAU         tina@generallogistics.net
# 3     0030N00002tXvvIQAS        bookings@delongcompany.com
# 4     0030N00002tXvvIQAS        bookings@delongcompany.com
# ..                   ...                               ...
# 995   0035p00003jNMpbAAG        colleen@hansenshipping.com
# 996                  NaN                               NaN
# 997   0035p00003a6QggAAE  usa.wccargoreadiness@cma-cgm.com
# 998   0030N000030dDDcQAM      lucychu-lax@e-cargogroup.com
# 999   0035p00003a6o7OAAQ             chi.jpark@cma-cgm.com
#
#                               LastIncomingEmailContent  \
# 0     \nThank you Jessica! Await your further on th...
# 1    \nHi Nese,\n \nInmiddels de aangepaste bl’s al...
# 2    \nHello,\nPlease SPLIT subject line booking to...
# 3    CMA CGM - Cut-off date change at - NEW YORK, N...
# 4    CMA CGM - Cut-off date change at - NEW YORK, N...
# ..                                                 ...
# 995  \nThank you very much for your help.  PayCargo...
# 996  \nHello, \n \nPlease see attached proof of pay...
# 997  \n@Export VIP - RIO TINTO\n \nPlease urgently ...
# 998  \nHi, \n \nNAM4947358B    low booking HOLD for...
# 999  **** THIS MESSAGE WAS TRUNCATED ****\nGood mor...
#
#      LastEmailCCAddressCount  CMA_in_cc  CountMailsInConversation  \
# 0                          1      False                         7
# 1                          5       True                         4
# 2                          1      False                         3
# 3                          1       True                         2
# 4                          0      False                         2
# ..                       ...        ...                       ...
# 995                        2      False                         2
# 996                        0      False                         2
# 997                        1       True                         1
# 998                        0      False                         2
# 999                        0      False                         2
#
#                                       LastEmailContent
# 0    await container pending update wang export man...
# 1    nese kind marine agency office hour emergency ...
# 2    split subject line booking x number x x bookin...
# 3    cutoff date change york send booking listed bo...
# 4    cutoff date change york send booking listed bo...
# ..                                                 ...
# 995  receipt attached colleen parkway suite busines...
# 996  attached proof payment release carrier recover...
# 997               export rio urgently reach doc loaded
# 998  low booking hold rating h code approval custom...
# 999  message truncated morning scarlet note attache...
#
# [1000 rows x 16 columns]

# %%
# load csv
df = pd.read_csv(path3)

# %%
# Out:
#    Type                                   LastEmailContent  \
# 0     0  thank you jessica await your further on the tw...
# 1     0  hi nese inmiddels de aangepaste bls al beschik...
# 2     0  hello please split subject line booking to the...
# 3     0  cma cgm cutoff date change at new york ny u up...
# 4     0  cma cgm cutoff date change at new york ny u up...
#
#                                           text_clean
# 0  thank jessica await two container pending upda...
# 1  hi nese inmiddels de aangepaste bls al beschik...
# 2  hello please split subject line booking nam x ...
# 3  cma cgm cutoff date change new york ny u upbew...
# 4  cma cgm cutoff date change new york ny u upbew...
