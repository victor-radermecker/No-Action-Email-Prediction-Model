# %%
import pandas as pd
from cleaning_pipeline import * 

import warnings
warnings.filterwarnings('ignore')

# automatically refresh imported modules
# %reload_ext autoreload
# %autoreload 2

# %%
# Store data locally for confidentiality reasons!
data_path = "/Users/victor/Documents/Confidential Dataset/ML_NOAC_NOVA_Extraction.csv"

# Read data
# df2 = pd.read_csv(data_path)

# %%
df = pd.DataFrame()
data_cleaning(df)
# Out:
# Cleaning starting...
# 100%|██████████| 2512/2512 [07:08<00:00,  5.86it/s]
# Cleaning completed. :)
#        index  CaseNumber  Type Topics                        TeamName  \
# 0     138772   101489451     1   T701  US-NOR-CMA-BKG-EXP-NSINTEGRITY
# 1     133269   101339212     0   T036    US-NOR-CMA-CS-STARS-SCHENKER
# 2     222406   102382342     0   T539      US-NOR-CMA-EXP-ELITE-EXXON
# 3     214182   102272102     0   T044     US-NOR-CMA-CS-EXP-PREFERRED
# 4      12881   100129591     1   T702     US-NOR-CMA-CS-EXP-PREFERRED
# ...      ...         ...   ...    ...                             ...
# 2507  188469   101992841     1   T701       US-NOR-CMA-BKG-EXP-COTTON
# 2508   96194   101014284     0   T042     US-NOR-CMA-EXP-ELITE-NESTLE
# 2509  246801   102032638     0   T018                  US-NOR-ANL-EXP
# 2510   51212   101082330     0   T037     US-NOR-CMA-BKG-EXP-PASCARGO
# 2511  159986   101710159     0   T052  US-NOR-CMA-BKG-EXP-SPECIALIZED
#
#                            RequesterEmail                      EmailObject  \
# 0         lourdes.grande@ictcshipping.com  RE: NAM5155872/NAM5162930/NAM5
# 1                diana.yii@dbschenker.com  RE: ***NOMINATE A VEESEL*** NA
# 2                     emltdocs@bdpint.com  OKAY TO RELEASE AT DESTINATION
# 3                     kason@cityocean.net   RE: CNPC020259 & NAM5047715 /
# 4            usa.chundley@usa.cma-cgm.com  RE: USATL REQUEST FOR LOADED R
# ...                                   ...                              ...
# 2507  whitneyclark@cofcointernational.com  RE: INDAMEX2 RE: DOC EXTENSION
# 2508          ssc.exportvipsi@cma-cgm.com  RE: container mismatch BKG#NAM
# 2509     ssc.uslaudit-release@cma-cgm.com  RE: ANL MCN Request BL#OCE0222
# 2510               kimberly@lenmarusa.com    RE: NAM5145198  [ ref:_00D0N
# 2511                ho.clecoq@cma-cgm.com   OA PNW2 - TWPKS - Amended LTS
#
#                                      LastEmailCCAddress       AttributesURL  \
# 0                                                   NaN  5005p00002h4z9LAAQ
# 1     us.sm.ord.tptococeanexportsarchiveonly@dbschen...  5005p00002h4BROAA2
# 2                             usa.exxon@usa.cma-cgm.com  5005p00002hIEnoAAG
# 3     ameriywang@cityocean.com; exp06.dl@charter-lin...  5005p00002hHeT6AAK
# 4     usa.logistics-westeast-rampdoor@usa.cma-cgm.co...  5005p00002gUDyVAAW
# ...                                                 ...                 ...
# 2507  mallorycofco@mallorygroup.com; usa.cmaexportac...  5005p00002h7gaGAAQ
# 2508  usa.cmaexportactive@usa.cma-cgm.com; usa.expdo...  5005p00002gletFAAQ
# 2509  gsc.micliu@cma-cgm.com; anl.revenuecontrol@cma...  5005p00002h7v9BAAQ
# 2510                              matthew@lenmarusa.com  5005p00002gfeUXAAY
# 2511  ho.twpksops@cma-cgm.com; ssc.psm@cma-cgm.com; ...  5005p00002h6BMmAAM
#
#      ContactAttributesURL                         ContactEmail  \
# 0      0030N00002wzsv9QAA      lourdes.grande@ictcshipping.com
# 1      0035p00003fJ20lAAC             diana.yii@dbschenker.com
# 2      0030N000035THbQQAW                  emltdocs@bdpint.com
# 3      0035p00003a6JhDAAU                  kason@cityocean.net
# 4      0030N00002LvFWMQA3         usa.chundley@usa.cma-cgm.com
# ...                   ...                                  ...
# 2507   0035p00003ers6lAAA  whitneyclark@cofcointernational.com
# 2508   0030N00002fXP1VQAW          ssc.exportvipsi@cma-cgm.com
# 2509   0030N00003Jqx17QAB     ssc.uslaudit-release@cma-cgm.com
# 2510   0035p00003UVq2zAAD               kimberly@lenmarusa.com
# 2511   0030N00002LvBBQQA3                ho.clecoq@cma-cgm.com
#
#                                LastIncomingEmailContent  \
# 0      OOPS\nYes – let me look for them.\n  \n   \n?...
# 1     **** THIS MESSAGE WAS TRUNCATED ****\nHello,\n...
# 2     P {margin-top:0;margin-bottom:0;}  \nHello,  P...
# 3     ***MESSAGE TRUNCATED***\n \n  Good day Cma,\n ...
# 4     \nApproved to late railbill for ingate. \nPlea...
# ...                                                 ...
# 2507  \nPERFECT THANK YOU \n😊\n \nThere was a reques...
# 2508  Good day, Reminder -4 Awaiting for your reply....
# 2509  \n \n \nDear team,\n \nKindly assist below mai...
# 2510  \nHi Team, Can we get an update on this spotti...
# 2511   Dear All, Good Day,\n \n1/ Schedule amendment...
#
#       LastEmailCCAddressCount  CMA_in_cc  CountMailsInConversation  \
# 0                           0      False                         0
# 1                           1      False                         0
# 2                           1       True                         0
# 3                           8      False                         0
# 4                           3       True                         0
# ...                       ...        ...                       ...
# 2507                        2       True                         0
# 2508                        3       True                         0
# 2509                        3       True                         0
# 2510                        1      False                         0
# 2511                        7       True                         0
#
#                                        LastEmailContent
# 0     integrity especially b customer service execut...
# 1     message truncated request empty container depo...
# 2                                                     p
# 3     message truncated day advise hold removed erro...
# 4     late ingate proceed request loaded rail billin...
# ...                                                 ...
# 2507  perfect request morning roll booking make happ...
# 2508  day reminder reply executive customer direct l...
# 2509  dear team kindly assist mail kind export custo...
# 2510  team update spotting advance shipping street s...
# 2511  dear day schedule amendment blank sailing nan ...
#
# [2512 rows x 16 columns]

# %%
# nltk.download('omw-1.4')
# nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /Users/victor/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True
