# %%
import pandas as pd
from collections import Counter
import itertools

# %%
customers = pd.read_csv('/content/drive/MyDrive/Google Colab - ALab/Data/Customer classifications.csv')

data = pd.read_csv('/content/drive/MyDrive/Google Colab - ALab/Data/ML_NOAC_NOVA_Extraction_Cleaned_DF3_Full.csv').dropna()

# %%
data.head()
# Out:
#     index  CaseNumber  Type Topics                  TeamName  \
# 2       2   100095395     0   T035  US-NOR-CMA-BKG-PREFERRED
# 3       3   100097054     0   T847  US-NOR-CMA-BKG-SPECIALTY
# 12     12   100109412     0   T035  US-NOR-CMA-BKG-SPECIALTY
# 13     13   100109413     0   T035  US-NOR-CMA-BKG-SPECIALTY
# 14     14   100109414     0   T035  US-NOR-CMA-BKG-SPECIALTY
#
#                       RequesterEmail                      EmailObject  \
# 2          tina@generallogistics.net    AMEND NAM5088900  [ ref:_00D
# 3         bookings@delongcompany.com  FW: CMA CGM - Cut-off date cha
# 12  erica.pavese@theredwoodgroup.com  RE: Detroit to gwangyang REDWO
# 13  erica.pavese@theredwoodgroup.com  RE: Detroit to gwangyang REDWO
# 14  erica.pavese@theredwoodgroup.com  RE: Detroit to gwangyang REDWO
#
#                      LastEmailCCAddress       AttributesURL  \
# 2         bookings@generallogistics.net  5005p00002evX4SAAU
# 3   usa.cmaexportactive@usa.cma-cgm.com  5005p00002evXIsAAM
# 12  usa.cmaexportactive@usa.cma-cgm.com  5005p00002evXg4AAE
# 13  usa.cmaexportactive@usa.cma-cgm.com  5005p00002evXg5AAE
# 14  usa.cmaexportactive@usa.cma-cgm.com  5005p00002evXg6AAE
#
#    ContactAttributesURL                      ContactEmail  \
# 2    0030N00002x1JqPQAU         tina@generallogistics.net
# 3    0030N00002tXvvIQAS        bookings@delongcompany.com
# 12   0030N00003JpqfxQAB  erica.pavese@theredwoodgroup.com
# 13   0030N00003JpqfxQAB  erica.pavese@theredwoodgroup.com
# 14   0030N00003JpqfxQAB  erica.pavese@theredwoodgroup.com
#
#                              LastIncomingEmailContent  \
# 2   \nHello,\nPlease SPLIT subject line booking to...
# 3   CMA CGM - Cut-off date change at - NEW YORK, N...
# 12  \nHi CMA,\n \nWanted to see if any bookings ha...
# 13  \nHi CMA,\n \nWanted to see if any bookings ha...
# 14  \nHi CMA,\n \nWanted to see if any bookings ha...
#
#     LastEmailCCAddressCount  CMA_in_cc  CountMailsInConversation  \
# 2                         1      False                         3
# 3                         1       True                         2
# 12                        1       True                         2
# 13                        1       True                         2
# 14                        1       True                         2
#
#                                      LastEmailContent
# 2   hello please split subject line booking to the...
# 3   cma cgm cutoff date change at new york ny u up...
# 12  hi cma wanted to see if any booking had been s...
# 13  hi cma wanted to see if any booking had been s...
# 14  hi cma wanted to see if any booking had been s...

# %%
customers.head()
# Out:
#    Row Num Customer Status  Status Detail  GA Service Level Customer Type  \
# 0        1             ACT            NaN  No     Preferred     Forwarder
# 1        2             ACT            NaN  No     Preferred     Forwarder
# 2        3             ACT            NaN  No     Preferred      Customer
# 3        4             ACT            NaN  No     Preferred     Forwarder
# 4        5             ACT            NaN  No     Preferred     Forwarder
#
#       UO Code                   UO Name  Partner Code  \
# 0  UO00002496             CARGOWAYS LLC        308962
# 1  UO00002496             CARGOWAYS LLC       1377769
# 2         NaN                       NaN       5055657
# 3  UO00000822  CAROLINA OCEAN LINES INC         18543
# 4  UO00041792              TMX SHIPPING        256782
#
#                    Partner name  ... REJ Week Rejected Date Rejected By  \
# 0           CARGOWAYS LOGISTICS  ...        -             -           -
# 1           CARGOWAYS LOGISTICS  ...        -             -           -
# 2  CARGOWAYS OCEAN SERVICES INC  ...        -             -           -
# 3      CAROLINA OCEAN LINES INC  ...        -             -           -
# 4           TMX SHIPPING CO INC  ...        -             -           -
#
#   Rejected by Name Rejected by Dpt Reason  Deactivation Status    Import Date  \
# 0                -               -      -                    -   1/26/04 0:00
# 1                -               -      -                    -   1/23/13 0:00
# 2                -               -      -                    -  11/13/18 0:00
# 3                -               -      -                    -   5/26/04 0:00
# 4                -               -      -                    -   2/17/04 0:00
#
#   Activation delay (after 30/04) HasBeenRejectedOnce
# 0                              -                  No
# 1                              -                  No
# 2                              -                  No
# 3                              -                  No
# 4                              -                  No
#
# [5 rows x 53 columns]

# %%
customers.columns
# Out:
# Index(['Row Num', 'Customer Status', 'Status Detail', 'GA', 'Service Level',
#        'Customer Type', 'UO Code', 'UO Name', 'Partner Code', 'Partner name',
#        'Partner Creation Date', 'Partner Status', 'Compliance Status',
#        'Partner Nature', 'Partner Country', 'Package', 'ACT Assoc. account',
#        'Referent', 'email', 'Domain', 'Nb Domain/Partner ACT/REJ', 'Public',
#        'Black listed domain', 'Multimapping', 'Business Case', 'Customer_Id',
#        'Customer RO', 'Customer Country', 'City',
#        'Registration Customer Company', 'First name', 'Last name',
#        'Internal account', 'Notification Flag', 'Channel', 'Created week',
#        'Created Date', 'Last Login Date', 'ACT Week', 'Activation Date',
#        'ActivatedBy', 'Activated By Name', 'Activated by Dpt', 'REJ Week',
#        'Rejected Date', 'Rejected By', 'Rejected by Name', 'Rejected by Dpt',
#        'Reason', 'Deactivation Status', 'Import Date',
#        'Activation delay (after 30/04)', 'HasBeenRejectedOnce'],
#       dtype='object')

# %%
Counter(customers['Service Level'])
# Out:
# Counter({'Preferred': 22410, 'Premier': 4411, 'Elite': 3536})

# %%
# keep only relevant features
customers = customers[['Service Level', 'Customer Type', 'Partner name', 'email', 'Notification Flag']]

# %%
data = data.reset_index()

# %%
data['LastEmailCCAddress']
# Out:
# 0                             bookings@generallogistics.net
# 1                       usa.cmaexportactive@usa.cma-cgm.com
# 2                       usa.cmaexportactive@usa.cma-cgm.com
# 3                       usa.cmaexportactive@usa.cma-cgm.com
# 4                       usa.cmaexportactive@usa.cma-cgm.com
#                                 ...
# 126196    spe@westernoverseas.com; may.tang@apl.com; ron...
# 126197    orf.wsaunders@cma-cgm.com; anishigaya@mgfgroup...
# 126198    orf.wsaunders@cma-cgm.com; anishigaya@mgfgroup...
# 126199    rfiexportrailbilling@cma-cgm.com; usa.mhackett...
# 126200    usa.tbriggs@usa.cma-cgm.com; usa.mguffie@usa.c...
# Name: LastEmailCCAddress, Length: 126201, dtype: object

# %%
# get email domain
import re

re.findall('@(.*)', data['LastEmailCCAddress'][126196].split('; ')[0])
# Out:
# ['westernoverseas.com']

# %%
# get all email domains from data
all_emails = list(set(list(itertools.chain.from_iterable([re.findall('@(.*)', item) for sublist in data['LastEmailCCAddress'] for item in sublist.split('; ')])) + 
                      list(itertools.chain.from_iterable([re.findall('@(.*)', item) for sublist in data['ContactEmail'] for item in sublist.split('; ')]))))

# %%
# get all email domains from customers
customers_emails = list(set(itertools.chain.from_iterable([re.findall('@(.*)', item) for item in customers['email']])))

# %%
print(len(all_emails), len(customers_emails))
# Out:
# 5642 8095

# %%
# check how many are in common
#len(set(all_emails) - set(customers_emails))
len(list(set(all_emails).intersection(customers_emails)))
# Out:
# 2645
