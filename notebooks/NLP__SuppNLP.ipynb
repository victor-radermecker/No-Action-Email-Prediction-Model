# %%
# !pip install datasets evaluate transformers[sentencepiece]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 441 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 72 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 5.5 MB 44.6 MB/s
# ...
#      |████████████████████████████████| 212 kB 47.2 MB/s
# ...
#      |████████████████████████████████| 95 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 115 kB 48.4 MB/s
# ...
#      |████████████████████████████████| 163 kB 10.5 MB/s
# ...
#      |████████████████████████████████| 127 kB 66.7 MB/s
# ...
#      |████████████████████████████████| 115 kB 58.7 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 37.5 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 49.4 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.6
# ...

# %%
# !pip install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 830 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 280 kB 52.7 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 46.3 MB/s
# ...
#   Created wheel for swifter: filename=swifter-1.3.4-py3-none-any.whl size=16322 sha256=24a1f1b66cdb8f613e6fda36ebf29b1811f5de6bab7b3332e227f8ebb83cb97b
#   Stored in directory: /root/.cache/pip/wheels/29/a7/0e/3a8f17ac69d759e1e93647114bc9bdc95957e5b0cbfd405205
# Successfully built swifter
# ...
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# ...

# %%
from transformers import pipeline
import pandas as pd
import math
# from transformers import AutoTokenizer, AutoModelForCausalLM

# from torch import nn
from tqdm import tqdm

tqdm.pandas()

# %%
# Import Dataset
from google.colab import drive
drive.mount('/content/drive')

# Read Csv File
data = pd.read_csv("/content/drive/MyDrive/ML_NOAC_NOVA_Extraction_Cleaned_DF4_Full.csv")

data = data[['CaseNumber', 'LastEmailContent']]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Clean the email text content because NaN causes an error in HuggingFace

# %%
def make_str(word):
  if not isinstance(word,str):
    return ""
  return str(word)

def introduce_empty(word):
    if not word or not isinstance(word, str) or len(word) == 0:
        return "[EMPTY]"
    return word

def clean_up_pipeline(sentence):
    cleaning_utils = [make_str,
                      #remove_hyperlink,
                      #replace_newline,
                      #to_lower,
                      #remove_number,
                      #remove_punctuation,
                      #remove_whitespace,
                      introduce_empty]

    for o in cleaning_utils:
        sentence = o(sentence)
    return sentence
  
data["LastEmailContent"] = data["LastEmailContent"].apply(lambda x: clean_up_pipeline(x))

# %%
#Partition data into separate data frames so that we don't lose progress during processing
x = math.floor(data.shape[0]/20)

data1 = data.iloc[0:x-1]
data2 = data.iloc[x:2*x-1]
data3 = data.iloc[2*x:3*x-1]
data4 = data.iloc[3*x:4*x-1]
data5 = data.iloc[4*x:5*x-1]
data6 = data.iloc[5*x:6*x-1]
data7 = data.iloc[6*x:7*x-1]
data8 = data.iloc[7*x:8*x-1]
data9 = data.iloc[8*x:9*x-1]
data10 = data.iloc[9*x:10*x-1]
data11 = data.iloc[10*x:11*x-1]
data12 = data.iloc[11*x:12*x-1]
data13 = data.iloc[12*x:13*x-1]
data14 = data.iloc[13*x:14*x-1]
data15 = data.iloc[14*x:15*x-1]
data16 = data.iloc[15*x:16*x-1]
data17 = data.iloc[16*x:17*x-1]
data18 = data.iloc[17*x:18*x-1]
data19 = data.iloc[18*x:19*x-1]
data20 = data.iloc[19*x:data.shape[0]]

dataList = [data1, data2, data3, data4, data5, data6, data7, data8, data9, data10,
        data11, data12, data13, data14, data15, data16, data17, data18, data19, data20]
  
dataList2 = [data11, data12, data13, data14, data15, data16, data17, data18, data19, data20]

# %%
#Printing the list of data frame lengths to confirm that they were built correctly
#All data frames have length 12560 except for data20 which has length 12575
for i in dataList:
  print(i.shape[0])
# Out:
# 12560
# 12560
# 12560
# 12560
# 12560
# 12560
# 12560
# 12560
# 12560
# 12560
# 12560
# 12560
# 12560
# 12560
# 12560
# 12560
# 12560
# 12560
# 12560
# 12575

# %%
#Initialize output Data Frame with just case numbers and results of supplemental NLP
output = pd.DataFrame(data = data['CaseNumber'])
type(output)
pd.DataFrame.head(output)
# Out:
#    CaseNumber
# 0   100124562
# 1   100080371
# 2   100095395
# 3   100097054
# 4   100097055

# %%
#Initialize HuggingFace Pipeline
tokenizer = "distilbert-base-uncased-finetuned-sst-2-english"
model = "distilbert-base-uncased-finetuned-sst-2-english"


sentClassifier = pipeline("sentiment-analysis", model = model, tokenizer = tokenizer)
# Out:
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
#Make list with the text content of each email in segment
list1 = data1['LastEmailContent'].tolist()
list2 = data2['LastEmailContent'].tolist()
list3 = data3['LastEmailContent'].tolist()
list4 = data4['LastEmailContent'].tolist()
list5 = data5['LastEmailContent'].tolist()
list6 = data6['LastEmailContent'].tolist()
list7 = data7['LastEmailContent'].tolist()
list8 = data8['LastEmailContent'].tolist()
list9 = data9['LastEmailContent'].tolist()
list10 = data10['LastEmailContent'].tolist()

#Create master list to more easily iterate through
masterList = [list1, list2, list3, list4, list5, list6, list7, list8, list9, list10]

# %%
list11 = data11['LastEmailContent'].tolist()
list12 = data12['LastEmailContent'].tolist()
list13 = data13['LastEmailContent'].tolist()
list14 = data14['LastEmailContent'].tolist()
list15 = data15['LastEmailContent'].tolist()
list16 = data16['LastEmailContent'].tolist()
list17 = data17['LastEmailContent'].tolist()
list18 = data18['LastEmailContent'].tolist()
list19 = data19['LastEmailContent'].tolist()
list20 = data20['LastEmailContent'].tolist()

masterList2 = [list11, list12, list13, list14, list15, list16, list17, list18, list19, list20]

# %%
#Create list of paths so that the outputs do not overwrite themselves
pathList = ["data1.csv", "data2.csv", "data3.csv", "data4.csv", "data5.csv", "data6.csv", "data7.csv", "data8.csv", "data9.csv", "data10.csv"]

# %%
pathList2 = ["data11.csv", "data12.csv", "data13.csv", "data14.csv", "data15.csv", "data16.csv", "data17.csv", "data18.csv", "data19.csv", "data20.csv"]

# %%
#Iterate through master list, generating a data frame with sentiment score and case number, and write it to a csv
for i in range(1,11):
  frame = pd.DataFrame((sentClassifier(masterList[i], padding = True, truncation = True)))
  frame['CaseNumber'] = dataList[i]['CaseNumber']
  path = "/content/drive/MyDrive/" + pathList[i]
  frame.to_csv(path, index=False, encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-5ec280e26920> in <module>
#       1 #Iterate through master list, generating a data frame with sentiment score and case number, and write it to a csv
#       2 for i in range(1,11):
# ----> 3   frame = pd.DataFrame((sentClassifier(masterList[i], padding = True, truncation = True)))
#       4   frame['CaseNumber'] = dataList[i]['CaseNumber']
#       5   path = "/content/drive/MyDrive/" + pathList[i]
#
# /usr/local/lib/python3.7/dist-packages/transformers/pipelines/text_classification.py in __call__(self, *args, **kwargs)
#     138             If `top_k` is used, one such dictionary is returned per label.
#     139         """
# --> 140         result = super().__call__(*args, **kwargs)
#     141         # TODO try and retrieve it in a nicer way from _sanitize_parameters.
# ...

# %%
#Iterate through master list, generating a data frame with sentiment score and case number, and write it to a csv
for i in range(1,11):
  frame = pd.DataFrame((sentClassifier(masterList2[i], padding = True, truncation = True)))
  frame.insert(loc=2,
          column='CaseNumber',
          value=dataList2[i]['CaseNumber'])
  path = "/content/drive/MyDrive/" + pathList2[i]
  frame.to_csv(path, index=False, encoding='utf-8-sig')

# %%
  frame9a = pd.DataFrame((sentClassifier(masterList2[9], padding = True, truncation = True)))
  #frame2a.insert(loc=2,
          #column='CaseNumber',
          #value=dataList2[1]['CaseNumber'])
  #path1 = "/content/drive/MyDrive/" + pathList2[1]
  #frame1.to_csv(path1, index=False, encoding='utf-8-sig')

  # frame2 = pd.DataFrame((sentClassifier(masterList2[9], padding = True, truncation = True)))
  # frame2.insert(loc=2,
  #         column='CaseNumber',
  #         value=dataList2[9]['CaseNumber'])
  # path2 = "/content/drive/MyDrive/" + pathList2[9]
  # frame2.to_csv(path2, index=False, encoding='utf-8-sig')

# %%
cases9a = dataList2[9]['CaseNumber'].tolist()

frame9a.insert(loc=2,
          column='CaseNumber',
          value=cases9a)

pd.DataFrame.head(frame9a)
# frame1.insert(loc=2,
#           column='CaseNumber',
#           value=dataList2[1]['CaseNumber'])

#frame1.drop('CaseNumber', axis=1, inplace=True)

#pd.DataFrame.head(frame1)
# Out:
#       label     score  CaseNumber
# 0  POSITIVE  0.849953   102522863
# 1  NEGATIVE  0.996173   102522583
# 2  NEGATIVE  0.996173   102524412
# 3  NEGATIVE  0.998862   102522852
# 4  POSITIVE  0.911010   102523130

# %%
path9a = "/content/drive/MyDrive/data19.csv"
frame9a.to_csv(path9a, index=False, encoding='utf-8-sig')

# %%
frame1.insert(loc=2,
          column='CaseNumber',
          value=dataList2[1]['CaseNumber'])

# %%
pd.DataFrame.head(frame1)

pd.DataFrame.head(frame1)

cases = dataList2[1]['CaseNumber'].tolist()
frame1.insert(loc=2,
  column='CaseNumber',
  value=cases)

# %%
pd.DataFrame.head(frame1)
# Out:
#       label     score  CaseNumber
# 0  NEGATIVE  0.993777   101487991
# 1  NEGATIVE  0.993493   101481621
# 2  NEGATIVE  0.994127   101481215
# 3  NEGATIVE  0.993521   101481241
# 4  NEGATIVE  0.998420   101480750

# %%
path = "/content/drive/MyDrive/" + pathList2[1]
frame1.to_csv(path, index=False, encoding='utf-8-sig')

# %%
frame3 = pd.DataFrame((sentClassifier(masterList2[10], padding = True, truncation = True)))
frame3.insert(loc=2,
  column='CaseNumber',
  value=dataList2[10]['CaseNumber'])
path3 = "/content/drive/MyDrive/" + pathList2[10]
frame3.to_csv(path3, index=False, encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8a8ac7ee5a22> in <module>
# ----> 1 frame3 = pd.DataFrame((sentClassifier(masterList2[10], padding = True, truncation = True)))
#       2 frame3.insert(loc=2,
#       3   column='CaseNumber',
#       4   value=dataList2[10]['CaseNumber'])
#       5 path3 = "/content/drive/MyDrive/" + pathList2[10]
#
# NameError: name 'pd' is not defined

# %%
frame = pd.DataFrame(sentClassifier(list1, padding = True, truncation = True))

# %%
frame['CaseNumber'] = data1['CaseNumber']

# %%
path = "/content/drive/MyDrive/data1.csv"

# %%
frame.to_csv(path, index =False, encoding='utf-8-sig')

# %%
sent1 = frame
sent2 = pd.read_csv("/content/drive/MyDrive/data2.csv")
sent3 = pd.read_csv("/content/drive/MyDrive/data3.csv")
sent4 = pd.read_csv("/content/drive/MyDrive/data4.csv")
sent5 = pd.read_csv("/content/drive/MyDrive/data5.csv")
sent6 = pd.read_csv("/content/drive/MyDrive/data6.csv")
sent7 = pd.read_csv("/content/drive/MyDrive/data7.csv")
sent8 = pd.read_csv("/content/drive/MyDrive/data8.csv")
sent9 = pd.read_csv("/content/drive/MyDrive/data9.csv")
sent10 = pd.read_csv("/content/drive/MyDrive/data10.csv")

# %%
sent1 = pd.read_csv("/content/drive/MyDrive/data1.csv")
sent2 = pd.read_csv("/content/drive/MyDrive/data2.csv")
sent3 = pd.read_csv("/content/drive/MyDrive/data3.csv")
sent4 = pd.read_csv("/content/drive/MyDrive/data4.csv")
sent5 = pd.read_csv("/content/drive/MyDrive/data5.csv")
sent6 = pd.read_csv("/content/drive/MyDrive/data6.csv")
sent7 = pd.read_csv("/content/drive/MyDrive/data7.csv")
sent8 = pd.read_csv("/content/drive/MyDrive/data8.csv")
sent9 = pd.read_csv("/content/drive/MyDrive/data9.csv")
sent10 = pd.read_csv("/content/drive/MyDrive/data10.csv")
sent11 = pd.read_csv("/content/drive/MyDrive/data11.csv")
sent12 = pd.read_csv("/content/drive/MyDrive/data12.csv")
sent13 = pd.read_csv("/content/drive/MyDrive/data13.csv")
sent14 = pd.read_csv("/content/drive/MyDrive/data14.csv")
sent15 = pd.read_csv("/content/drive/MyDrive/data15.csv")
sent16 = pd.read_csv("/content/drive/MyDrive/data16.csv")
sent17 = pd.read_csv("/content/drive/MyDrive/data17.csv")
sent18 = pd.read_csv("/content/drive/MyDrive/data18.csv")
sent19 = pd.read_csv("/content/drive/MyDrive/data19.csv")
sent20 = pd.read_csv("/content/drive/MyDrive/data20.csv")

# %%
sent1 = frame

# %%
pd.DataFrame.head(sent2)
# Out:
#       label     score  CaseNumber
# 0  POSITIVE  0.995772         NaN
# 1  NEGATIVE  0.999511         NaN
# 2  POSITIVE  0.503710         NaN
# 3  NEGATIVE  0.999685         NaN
# 4  NEGATIVE  0.975900         NaN

# %%
case2 = data2['CaseNumber'].tolist()

sent2.insert(loc=2,
          column='CaseNumber',
          value=case2)

# %%
pd.DataFrame.head(sent2)
# Out:
#       label     score  CaseNumber
# 0  POSITIVE  0.995772   100128236
# 1  NEGATIVE  0.999511   100127670
# 2  POSITIVE  0.503710   100128222
# 3  NEGATIVE  0.999685   100129558
# 4  NEGATIVE  0.975900   100128759

# %%
# Out:
# 12561    100128236
# 12562    100127670
# 12563    100128222
# 12564    100129558
# 12565    100128759
#            ...
# 25116    100168780
# 25117    100168772
# 25118    100168890
# 25119    100168783
# 25120    100169345
# Name: CaseNumber, Length: 12560, dtype: int64

# %%
sent2.drop('CaseNumber', axis=1, inplace=True)
sent3.drop('CaseNumber', axis=1, inplace=True)
sent4.drop('CaseNumber', axis=1, inplace=True)
sent5.drop('CaseNumber', axis=1, inplace=True)
sent6.drop('CaseNumber', axis=1, inplace=True)
sent7.drop('CaseNumber', axis=1, inplace=True)
sent8.drop('CaseNumber', axis=1, inplace=True)
sent9.drop('CaseNumber', axis=1, inplace=True)
sent10.drop('CaseNumber', axis=1, inplace=True)

# %%
case2 = data2['CaseNumber'].tolist()
case3 = data3['CaseNumber'].tolist()
case4 = data4['CaseNumber'].tolist()
case5 = data5['CaseNumber'].tolist()
case6 = data6['CaseNumber'].tolist()
case7 = data7['CaseNumber'].tolist()
case8 = data8['CaseNumber'].tolist()
case9 = data9['CaseNumber'].tolist()
case10 = data10['CaseNumber'].tolist()

# %%
sent2.insert(loc=2,
          column='CaseNumber',
          value=case2)
sent3.insert(loc=2,
          column='CaseNumber',
          value=case3)
sent4.insert(loc=2,
          column='CaseNumber',
          value=case4)
sent5.insert(loc=2,
          column='CaseNumber',
          value=case5)
sent6.insert(loc=2,
          column='CaseNumber',
          value=case6)
sent7.insert(loc=2,
          column='CaseNumber',
          value=case7)
sent8.insert(loc=2,
          column='CaseNumber',
          value=case8)
sent9.insert(loc=2,
          column='CaseNumber',
          value=case9)
sent10.insert(loc=2,
          column='CaseNumber',
          value=case10)

# %%
pd.DataFrame.head(sent10)
# Out:
#       label     score  CaseNumber
# 0  NEGATIVE  0.956553   101117841
# 1  NEGATIVE  0.595452   101117850
# 2  NEGATIVE  0.974225   101117872
# 3  NEGATIVE  0.999685   101121139
# 4  NEGATIVE  0.595452   101117864

# %%
frames_to_cat = [sent1, sent2, sent3, sent4, sent5, sent6, sent7, sent8, sent9, sent10,
                 sent11, sent12, sent13, sent14, sent15, sent16, sent17, sent18, sent19, sent20]
sentFinal = pd.concat(frames_to_cat)

# %%
sentFinal.to_csv("/content/drive/MyDrive/final_sentimentsv2.csv", index =False, encoding='utf-8-sig')

# %%
#Create list of paths so that the outputs do not overwrite themselves
pathList3z = ["zs1.csv", "zs2.csv", "zs3.csv", "zs4.csv", "zs5.csv", "zs6.csv", "zs7.csv", "zs8.csv", "zs9.csv", "zs10.csv",
              "zs11.csv", "zs12.csv", "zs13.csv", "zs14.csv", "zs15.csv", "zs16.csv", "zs17.csv", "zs18.csv", "zs19.csv", "zs20.csv"]

# %%
#Initialize HuggingFace Pipeline
tokenizer2 = "facebook/bart-large-mnli"
model2 = "facebook/bart-large-mnli"

zeroClassifier = pipeline("zero-shot-classification", model = model2, tokenizer = tokenizer2)
zeroClassifier("That's all I needed",
               padding = True, 
               truncation = True,
               candidate_labels=["help", "support", "request", "thankful"])
# Out:
# Downloading:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# {'sequence': "That's all I needed",
#  'labels': ['help', 'thankful', 'support', 'request'],
#  'scores': [0.36722227931022644,
#   0.2886529862880707,
#   0.20421673357486725,
#   0.13990801572799683]}

# %%
classify = zeroClassifier("That's all I needed",
               padding = True, 
               truncation = True,
               candidate_labels=["help", "support", "request", "thankful"])

# %%
listB = [data1['LastEmailContent'].tolist()[2], data1['LastEmailContent'].tolist()[3]]
frameB = pd.DataFrame(zeroClassifier(listB, padding = True, truncation = True, candidate_labels=["help", "support", "request", "thankful"]))

# %%
cases = [1001, 1111]
frameB.insert(loc=3, column = 'CaseNumber', value = cases)

# %%
pd.DataFrame.head(frameB)
# Out:
#                                             sequence  \
# 0  hello please split subject line booking to the...
# 1  cma cgm cutoff date change at new york ny us u...
#
#                                labels  \
# 0  [help, request, thankful, support]
# 1  [thankful, request, help, support]
#
#                                               scores  CaseNumber
# 0  [0.3524444103240967, 0.33654728531837463, 0.17...        1001
# 1  [0.45908233523368835, 0.21379323303699493, 0.1...        1111

# %%
list1 = data1['LastEmailContent'].tolist()
list2 = data2['LastEmailContent'].tolist()
list3 = data3['LastEmailContent'].tolist()
list4 = data4['LastEmailContent'].tolist()
list5 = data5['LastEmailContent'].tolist()
list6 = data6['LastEmailContent'].tolist()
list7 = data7['LastEmailContent'].tolist()
list8 = data8['LastEmailContent'].tolist()
list9 = data9['LastEmailContent'].tolist()
list10 = data10['LastEmailContent'].tolist()
list11 = data11['LastEmailContent'].tolist()
list12 = data12['LastEmailContent'].tolist()
list13 = data13['LastEmailContent'].tolist()
list14 = data14['LastEmailContent'].tolist()
list15 = data15['LastEmailContent'].tolist()
list16 = data16['LastEmailContent'].tolist()
list17 = data17['LastEmailContent'].tolist()
list18 = data18['LastEmailContent'].tolist()
list19 = data19['LastEmailContent'].tolist()
list20 = data20['LastEmailContent'].tolist()

#Create master list to more easily iterate through
masterList3 = [list1, list2, list3, list4, list5, list6, list7, list8, list9, list10,
               list11, list12, list13, list14, list15, list16, list17, list18, list19, list20]

# %%
#Iterate through master list, generating a data frame with sentiment score and case number, and write it to a csv
for i in range(1,21):
  frame3z = pd.DataFrame(zeroClassifier(masterList3[i], padding = True, truncation = True, candidate_labels=["help", "support", "request", "thankful"]))
  case3z = dataList[i]['CaseNumber'].tolist()
  frame3z.insert(loc=3,
          column='CaseNumber',
          value=case3z)
  path3z = "/content/drive/MyDrive/" + pathList3z[i]
  frame3z.to_csv(path3z, index=False, encoding='utf-8-sig')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4ca077d2aeba> in <module>
# ----> 1 frame3z
#
# NameError: name 'frame3z' is not defined
